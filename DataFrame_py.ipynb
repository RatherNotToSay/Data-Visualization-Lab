# %%
# Name : Aditya Khandelwal
# Roll no : 21     Batch :T2


import pandas as pd
data = {
    "Author":
    {
        "0":"Priyanshu",
        "1":"Nilesh",
        "2":"Adtiya",
        "3":"Priyanshu"
    },
    "Publisher":
    {
        "0":"MgrawHill",
        "1":"penguin",
        "2":"white book",
        "3":"Mgrawhill",
    },
    "Age":
    {
        "0":"20",
        "1":"19",
        "2":"21",
        "3":"20",
    }
}
df = pd.DataFrame(data)
# print(len(data))
# rows = len(df.axes[0])
# cols = len(df.axes[1])
# print(rows)
# print(cols)
print(df.duplicated(keep=False))
# df.duplicated(keep="first")
df
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
#       Author   Publisher Age
# 0  Priyanshu   MgrawHill  20
# 1     Nilesh     penguin  19
# 2     Adtiya  white book  21
# 3  Priyanshu   Mgrawhill  20

# %%
import pandas as pd
data = {
    "Author":
    {
        "0":"Priyanshu",
        "1":"Nilesh",
        "2":"NaN",
    },
    "Publisher":
    {
        "0":"MgrawHill",
        "1":"penguin",
        "2":"white book"
    },
    "Age":
    {
        "0":"NaN",
        "1":"19",
        "2":"21",
    }
}
df = pd.DataFrame(data)
# print(len(data))
# rows = len(df.axes[0])
# cols = len(df.axes[1])
# print(rows)
# print(cols)
df.dropna(inplace=True)
df

# %%
import pandas as pd

df = pd.read_json("author.json")
df
# Out:
#       Author   Publisher  Age
# 0  Priyanshu   MgrawHill   20
# 1     Nilesh     penguin   19
# 2     Adtiya  white book   21

# %% [markdown]
# # New Section
