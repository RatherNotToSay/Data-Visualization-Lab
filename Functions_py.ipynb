# %%
# Name : Aditya Khandelwal
# Roll no : 21     Batch :T2

import pandas as pd
df = pd.read_excel("/content/Marks (1).xlsx")
#sap id ke series ko series me print kiya
ser = pd.Series(df['SAP ID'])
#all values ko number se sort karr diya baba
sor = ser.sort_values()
sor
# Out:
# 60    14003200001
# 34    14004200001
# 57    14004200002
# 59    14004200003
# 16    14004200004
#          ...
# 62    14004210065
# 64    14004210066
# 65    14004210067
# 63    14004210068
# 66    14004210069
# Name: SAP ID, Length: 67, dtype: int64

# %%
import pandas as pd
df = pd.read_excel("/content/Marks (1).xlsx")
#sap id ke series ko series me print kiya
ser = pd.Series(df['SAP ID'])
d = ser.count()
d
# Out:
# 67

# %%
import pandas as pd
#print(pd.Timedelta("5 days 4 hours 12 minutes 30 seconds"))
#print(pd.Timedelta(days=4))
#print(pd.Timedelta(12,unit = "d"))
p=pd.Series(pd.date_range("2020-1-1",periods=3,freq="D"))
pr=pd.Series(pd.Timedelta(days=i) for i in range(3))
pri=pd.DataFrame(dict(A=p,B=pr))
pri["C"] = pri['A'] + pri['B']
pri
# Out:
#            A      B          C
# 0 2020-01-01 0 days 2020-01-01
# 1 2020-01-02 1 days 2020-01-03
# 2 2020-01-03 2 days 2020-01-05
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['B'],)"
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['index'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
# # reshaping the data
# df['Gender'] = df['Gender'].map({'M':1,'F':0})
# df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
df1 = pd.DataFrame({'ID' :["1","2","3"] ,
                    'Name':['prem','nilesh','om']})
df2 = pd.DataFrame({'ID' :["1","2","3"] ,
                    'Marks':['03','20','21']})
print(pd.merge(df1,df2,on = 'ID'))
# Out:
#   ID    Name Marks
# 0  1    prem    03
# 1  2  nilesh    20
# 2  3      om    21
